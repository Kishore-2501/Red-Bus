# %% [markdown]
# # Feature Extraction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# %%
orders = pd.read_csv("/content/orders.csv")
products = pd.read_csv("/content/products.csv")
order_products_train = pd.read_csv("/content/order_products__train.csv")
order_products_prior = pd.read_csv("/content/order_products__prior.csv")
aisles = pd.read_csv("/content/aisles.csv")
departments = pd.read_csv("/content/departments.csv")

# %% [markdown]
# ### Preparing Data

# %%
prior_df = order_products_prior.merge(orders, on ='order_id', how='inner')
prior_df = prior_df.merge(products, on = 'product_id', how = 'left')
prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         8       23423                1.0        1.0     3107    prior
# 1        40       10070                1.0        1.0      382    prior
# 2        40       42450                2.0        1.0      382    prior
# 3        40       33198                3.0        1.0      382    prior
# 4        40       34866                4.0        1.0      382    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0           5.0        4.0                6.0                    17.0
# 1          29.0        1.0               15.0                    23.0
# 2          29.0        1.0               15.0                    23.0
# 3          29.0        1.0               15.0                    23.0
# 4          29.0        1.0               15.0                    23.0
#
#                       product_name  aisle_id  department_id
# 0    Original Hawaiian Sweet Rolls        43              3
# 1          Organic 1% Low Fat Milk        84             16
# 2                Macaroni & Cheese        38              1
# 3  Sparkling Natural Mineral Water       115              7
# 4        Chocolate Milk 1% Milkfat        84             16

# %% [markdown]
# ## Features creation

# %% [markdown]
# Calculating how many times a user buy the product

# %%
prior_df['user_product_purchase_count'] = prior_df.groupby(['user_id', 'product_id']).cumcount() + 1
prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         8       23423                1.0        1.0     3107    prior
# 1        40       10070                1.0        1.0      382    prior
# 2        40       42450                2.0        1.0      382    prior
# 3        40       33198                3.0        1.0      382    prior
# 4        40       34866                4.0        1.0      382    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0           5.0        4.0                6.0                    17.0
# 1          29.0        1.0               15.0                    23.0
# 2          29.0        1.0               15.0                    23.0
# 3          29.0        1.0               15.0                    23.0
# 4          29.0        1.0               15.0                    23.0
#
#                       product_name  aisle_id  department_id  \
# 0    Original Hawaiian Sweet Rolls        43              3
# 1          Organic 1% Low Fat Milk        84             16
# 2                Macaroni & Cheese        38              1
# 3  Sparkling Natural Mineral Water       115              7
# 4        Chocolate Milk 1% Milkfat        84             16
#
#    user_buy_product_times  user_product_purchase_count
# 0                       1                            1
# 1                       1                            1
# 2                       1                            1
# 3                       1                            1
# 4                       1                            1

# %%
prod_feats1.to_pickle(root + 'product_features.pkl')
user_feats.to_pickle(root +'user_features.pkl')
user_product_feats.to_pickle(root +'user_product_features.pkl')
